# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\kaust\OneDrive\Desktop\housetrain.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df["LotShape"].unique()
# Out:
# array(['Reg', 'IR1', 'IR2', 'IR3'], dtype=object)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
sns.regplot(y="LotFrontage",x="SalePrice",data=df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.countplot(x="SalePrice",data=df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
sns.regplot(x="YearBuilt",y="SalePrice",data=df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
sns.barplot(x="Condition1",y="SalePrice",data=df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
sns.barplot(x="Condition2",y="SalePrice",data=df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 8)
sns.barplot(x="SaleType",y="SalePrice",data=df)

# %%
sns.pairplot(df[["GarageCars","GarageYrBlt","GarageArea","SalePrice"]],kind="reg")

# %%
sns.pairplot(df[["OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","SalePrice"]],kind="reg",dropna=True)

# %%
plt.figure(figsize=(25, 15))
plt.subplot(2,2,1)
sns.boxplot(x = 'GarageType', y = 'SalePrice', data = df)
plt.subplot(2,2,2)
sns.boxplot(x = 'GarageFinish', y = 'SalePrice', data = df)
plt.subplot(2,2,3)
sns.boxplot(x = 'GarageQual', y = 'SalePrice', data = df)
plt.subplot(2,2,4)
sns.boxplot(x = 'GarageCond', y = 'SalePrice', data = df)
plt.show()

# %%
plt.figure(figsize=(25, 15))
plt.subplot(3,3,1)
sns.boxplot(x = 'CentralAir', y = 'SalePrice', data = df)
plt.subplot(3,3,2)
sns.boxplot(x = 'Electrical', y = 'SalePrice', data = df)
plt.subplot(3,3,3)
sns.boxplot(x = 'KitchenQual', y = 'SalePrice', data = df)
plt.subplot(3,3,4)
sns.boxplot(x = 'Functional', y = 'SalePrice', data = df)
plt.subplot(3,3,5)
sns.boxplot(x = 'FireplaceQu', y = 'SalePrice', data = df)

# %%
plt.figure(figsize=(25, 15))
plt.subplot(3,3,1)
sns.boxplot(x = 'PavedDrive', y = 'SalePrice', data = df)
plt.subplot(3,3,2)
sns.boxplot(x = 'SaleType', y = 'SalePrice', data = df)
plt.subplot(3,3,3)
sns.boxplot(x = 'SaleCondition', y = 'SalePrice', data = df)
plt.show()

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
missing(df)
# Out:
# PoolQC           99.52
# MiscFeature      96.30
# Alley            93.77
# Fence            80.75
# FireplaceQu      47.26
# LotFrontage      17.74
# GarageCond        5.55
# GarageType        5.55
# GarageYrBlt       5.55
# GarageFinish      5.55
# GarageQual        5.55
# BsmtExposure      2.60
# BsmtFinType2      2.60
# BsmtFinType1      2.53
# BsmtCond          2.53
# BsmtQual          2.53
# MasVnrArea        0.55
# MasVnrType        0.55
# Electrical        0.07
# Utilities         0.00
# YearRemodAdd      0.00
# MSSubClass        0.00
# Foundation        0.00
# ExterCond         0.00
# ExterQual         0.00
# Exterior2nd       0.00
# Exterior1st       0.00
# RoofMatl          0.00
# RoofStyle         0.00
# YearBuilt         0.00
#                  ...
# GarageArea        0.00
# PavedDrive        0.00
# WoodDeckSF        0.00
# OpenPorchSF       0.00
# 3SsnPorch         0.00
# BsmtUnfSF         0.00
# ScreenPorch       0.00
# PoolArea          0.00
# MiscVal           0.00
# ...

# %%
df.drop("Alley",axis=1,inplace=True)
df.drop("PoolQC",axis=1,inplace=True)
df.drop("Fence",axis=1,inplace=True)
df.drop("MiscFeature",axis=1,inplace=True)
df.drop("GarageYrBlt",axis=1,inplace=True)
df.drop("Id",axis=1,inplace=True)

# %%
df["FireplaceQu"]=df["FireplaceQu"].fillna(df["FireplaceQu"].mode()[0])
df["GarageType"]=df["GarageType"].fillna(df["GarageType"].mode()[0])
df["GarageFinish"]=df["GarageFinish"].fillna(df["GarageFinish"].mode()[0])
df["GarageQual"]=df["GarageQual"].fillna(df["GarageQual"].mode()[0])
df["GarageCond"]=df["GarageQual"].fillna(df["GarageCond"].mode()[0])
df["BsmtQual"]=df["BsmtQual"].fillna(df["BsmtQual"].mode()[0])
df["MasVnrType"]=df["MasVnrType"].fillna(df["MasVnrType"].mode()[0])
df["MasVnrArea"]=df["MasVnrArea"].fillna(df["MasVnrArea"].mean())
df["LotFrontage"] = df["LotFrontage"].fillna(df["LotFrontage"].mean())

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
df.count()
# Out:
# MSSubClass       1420
# MSZoning         1420
# LotFrontage      1420
# LotArea          1420
# Street           1420
# LotShape         1420
# LandContour      1420
# Utilities        1420
# LotConfig        1420
# LandSlope        1420
# Neighborhood     1420
# Condition1       1420
# Condition2       1420
# BldgType         1420
# HouseStyle       1420
# OverallQual      1420
# OverallCond      1420
# YearBuilt        1420
# YearRemodAdd     1420
# RoofStyle        1420
# RoofMatl         1420
# Exterior1st      1420
# Exterior2nd      1420
# MasVnrType       1420
# MasVnrArea       1420
# ExterQual        1420
# ExterCond        1420
# Foundation       1420
# BsmtQual         1420
# BsmtCond         1420
#                  ...
# BsmtFullBath     1420
# BsmtHalfBath     1420
# FullBath         1420
# HalfBath         1420
# BedroomAbvGr     1420
# KitchenAbvGr     1420
# KitchenQual      1420
# TotRmsAbvGrd     1420
# Functional       1420
# Fireplaces       1420
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
df_float = df.select_dtypes(include=['float64']).copy()
df_float.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1420 entries, 0 to 1459
# Data columns (total 2 columns):
# LotFrontage    1420 non-null float64
# MasVnrArea     1420 non-null float64
# dtypes: float64(2)
# memory usage: 33.3 KB

# %%
df_float.describe()
# Out:
#        LotFrontage   MasVnrArea
# count  1420.000000  1420.000000
# mean     70.139887   105.357382
# std      22.272115   181.825921
# min      21.000000     0.000000
# 25%      60.000000     0.000000
# 50%      70.049958     0.000000
# 75%      79.000000   168.000000
# max     313.000000  1600.000000

# %%
lr_1=LinearRegression()
lr_2=LinearRegression()

# %%
lr_1.fit(df[["LotFrontage"]],df["SalePrice"])
lr_2.fit(df[["MasVnrArea"]],df["SalePrice"])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error

# %%
print(lr_1.coef_)
print(lr_1.intercept_)
print(mean_squared_error(df["SalePrice"], lr_1.predict(df[["LotFrontage"]])))
# Out:
# [1194.89272448]
# 99001.47840328774
# 5596076904.898882

# %%
print(lr_1.coef_)
print(lr_1.intercept_)
print(mean_squared_error(df["SalePrice"], lr_1.predict(df[["MasVnrArea"]])))
# Out:
# [1194.89272448]
# 99001.47840328774
# 38958199707.660774

# %%
np.sqrt(mean_squared_error(df["SalePrice"], lr_1.predict(df[["LotFrontage"]])))
# Out:
# 74806.93086137729

# %%
np.sqrt(mean_squared_error(df["SalePrice"], lr_1.predict(df[["MasVnrArea"]])))
# Out:
# 197378.3162043409
